# %% [markdown]
# ---
# title: "DSAN 5000 lab 1.2 Slides"
# author: "Yanni (Jen) Guo"
# format: revealjs
# echo: TRUE
# bibliography: ../reference.bib
# ---

# %% [markdown]
# ## Introduction to Jen
#
# <img src="images/Jen Guo.png" alt="Jen">

# %% [markdown]
# ## Washington, D.C. {.scrollable}
#
# <img src="images/Washington3.png" alt="Washington DC">

# %% [markdown]
# ## Python Graph

# %%
## Python Graph
#| code-fold: true
#| echo: true
#| code-overflow: true
#| code-summary: "Code"

import matplotlib.pyplot as plt
import numpy as np

x_axis_points = np.array([2,5,8])
y_axis_points = np.array([5,4,6])

plt.plot(x_axis_points, y_axis_points, 'o')
plt.show()

# %% [markdown]
# ## References
#
# The following is a citiation about the "R in Data Science" book: @wickham2023r
